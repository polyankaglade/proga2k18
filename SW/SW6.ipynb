# %%
#import for reading urls
import urllib.request
#import for parsing html
from bs4 import BeautifulSoup
#non-local page this time
link = "http://www.vpravda.ru/politika/delegaciya-iz-germanii-pobyvala-u-volgogradskogo-vechnogo-ognya-60334"
#connect to that page
f = urllib.request.urlopen(link)
#read it all in
myfile = f.read()
#build a document model
soup = BeautifulSoup(myfile,'html.parser')
#print the page verbatim
# print(myfile)

#pretty-print the html
print(soup.prettify())
#extract the text
   #print(soup.get_text())
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="iem7"  lang="ru" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="ru" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="ru" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="lt-ie9"  lang="ru" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!-->
# <html dir="ltr" lang="ru" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <script async="async" defer="defer" src="https://www.google.com/recaptcha/api.js?hl=ru">
#   </script>
#   <link href="http://www.vpravda.ru/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <meta content="Как сообщает пресс-служба Волгоградской городской думы, в немецкую делегацию вошли парламентарии из партии «Левые». – Гости пробудут в Волгограде три дня в рамках продвижения сотрудничества между Россией и Германией, – отметили в думе. Сегодня, 2 октября, депутаты Европейского парламента, бундестага и региональных парламентов ФРГ в сопровождении волгоградских политиков приняли участие в церемонии возложения венков и живых цветов к Вечному огню. Память сталинградских воинов собравшиеся почтили минутой молчания." name="description"/>
#   <meta content="Drupal 7 (http://drupal.org)" name="generator"/>
#   <link href="http://www.vpravda.ru/politika/delegaciya-iz-germanii-pobyvala-u-volgogradskogo-vechnogo-ognya-60334" rel="canonical"/>
#   <link href="http://www.vpravda.ru/node/60334" rel="shortlink"/>
#   <meta content="Волгоградская Правда" property="og:site_name"/>
#   <meta content="article" property="og:type"/>
#   <meta content="http://www.vpravda.ru/politika/delegaciya-iz-germanii-pobyvala-u-volgogradskogo-vechnogo-ognya-60334" property="og:url"/>
#   <meta content="Делегация из Германии побывала у волгоградского Вечного огня" property="og:title"/>
#   <meta content="Как сообщает пресс-служба Волгоградской городской думы, в немецкую делегацию вошли парламентарии из партии «Левые». – Гости пробудут в Волгограде три дня в рамках продвижения сотрудничества между Россией и Германией, – отметили в думе. Сегодня, 2 октября, депутаты Европейского парламента, бундестага и региональных парламентов ФРГ в сопровождении волгоградских политиков приняли участие в церемонии возложения венков и живых цветов к Вечному огню. Память сталинградских воинов собравшиеся почтили минутой молчания." property="og:description"/>
#   <meta content="2018-10-02T16:39:42+03:00" property="og:updated_time"/>
#   <meta content="http://www.vpravda.ru/sites/default/files/article/2018-10-02/59661-1538486573.jpg" property="og:image"/>
#   <meta content="image/jpeg" property="og:image:type"/>
#   <meta content="800" property="og:image:width"/>
#   <meta content="479" property="og:image:height"/>
#   <meta content="2018-10-02T16:22:53+03:00" property="article:published_time"/>
#   <meta content="2018-10-02T16:39:42+03:00" property="article:modified_time"/>
#   <meta content="77dc9107b035110b" name="yandex-verification"/>
#   <title>
#    Делегация из Германии побывала у волгоградского Вечного огня | Волгоградская Правда
#   </title>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!--[if IEMobile]><meta http-equiv="cleartype" content="on"><![endif]-->
#   <link href="http://fonts.googleapis.com/css?family=PT+Sans+Narrow:700,regular|PT+Serif:regular,italic,700,700italic|Roboto:regular,italic,700,700italic&amp;subset=cyrillic" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.vpravda.ru/sites/default/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.vpravda.ru/sites/default/files/css/css_6YiYkEK0g0n5-m5oDwVRTcq6WheaUCBYxeedCbF2oXw.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.vpravda.ru/sites/default/files/css/css_PGbJgHCUCBf4dg7K9Kt8aAwsApndP4GZ9RuToPy3-Fk.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.vpravda.ru/sites/default/files/css/css_MBgA2bwZRR0K-VxvOEPbs-5AYhS7_5gDcHMVSrkaruo.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://fonts.googleapis.com/css?family=PT+Sans+Narrow:700,regular|Roboto:500,500italic,700,700italic&amp;subset=cyrillic" media="all" rel="stylesheet" type="text/css"/>
#   <script src="http://www.vpravda.ru/sites/all/modules/jquery_update/replace/jquery/1.10/jquery.min.js?v=1.10.2">
#   </script>
#   <script src="http://www.vpravda.ru/misc/jquery.once.js?v=1.2">
#   </script>
#   <script src="http://www.vpravda.ru/misc/drupal.js?p9wo8n">
#   </script>
#   <script src="http://www.vpravda.ru/sites/all/modules/extlink/extlink.js?p9wo8n">
#   </script>
#   <script src="http://www.vpravda.ru/sites/default/files/languages/ru_D7aeJME2q2VfVIjmLuIv_gl57XsjlIE9phi_qhuY_Q4.js?p9wo8n">
#   </script>
#   <script src="http://www.vpravda.ru/sites/all/modules/captcha/captcha.js?p9wo8n">
#   </script>
#   <script src="http://www.vpravda.ru/sites/all/modules/zz_iv/zz_iv_voting/js/zz_iv_voting.js?p9wo8n">
#   </script>
#   <script src="http://www.vpravda.ru/misc/textarea.js?v=7.59">
#   </script>
#   <script src="http://www.vpravda.ru/sites/all/themes/vpravda/js/script.js?p9wo8n">
#   </script>
#   <script>
#    jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"vpravda","theme_token":"qFLVs_CmjqwhKYkCSR9GAX0NcoHh0HSgyG8_yo3pkfI","js":{"modules\/statistics\/statistics.js":1,"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.10\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/extlink\/extlink.js":1,"public:\/\/languages\/ru_D7aeJME2q2VfVIjmLuIv_gl57XsjlIE9phi_qhuY_Q4.js":1,"sites\/all\/modules\/captcha\/captcha.js":1,"sites\/all\/modules\/zz_iv\/zz_iv_voting\/js\/zz_iv_voting.js":1,"misc\/textarea.js":1,"sites\/all\/themes\/vpravda\/js\/script.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"modules\/comment\/comment.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/extlink\/extlink.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/themes\/vpravda\/system.menus.css":1,"sites\/all\/themes\/vpravda\/system.messages.css":1,"sites\/all\/themes\/vpravda\/system.theme.css":1,"sites\/all\/themes\/vpravda\/css\/styles.css":1,"http:\/\/fonts.googleapis.com\/css?family=PT+Sans+Narrow:700,regular|Roboto:500,500italic,700,700italic\u0026subset=cyrillic":1}},"extlink":{"extTarget":"_blank","extClass":"ext","extLabel":"(link is external)","extImgClass":0,"extIconPlacement":"append","extSubdomains":1,"extExclude":"","extInclude":"","extCssExclude":"","extCssExplicit":"","extAlert":0,"extAlertText":"This link will take you to an external web site.","mailtoClass":0,"mailtoLabel":"(link sends e-mail)"},"urlIsAjaxTrusted":{"\/comment\/reply\/60334":true},"statistics":{"data":{"nid":"60334"},"url":"\/modules\/statistics\/statistics.php"}});
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/sites/all/themes/zen/js/html5-respond.js"></script>
#     <![endif]-->
#  </head>
#  <body class="html not-front not-logged-in one-sidebar sidebar-second page-node page-node- page-node-60334 node-type-article section-politika">
#   <p id="skip-link">
#    <a class="element-invisible element-focusable" href="#main-menu">
#     Jump to navigation
#    </a>
#   </p>
#   <div id="top">
#    <div class="region region-top">
#     <div class="block block-zz-iv first last odd" id="block-zz-iv-zz-iv-top-links">
#      <ul class="clearfix">
#       <li>
#        <a class="active">
#         Волгоградская Правда
#        </a>
#       </li>
#       <li>
#        <a href="http://vv-34.ru/" rel="nofollow" target="_blank">
#         Вечерний Волгоград
#        </a>
#       </li>
#       <li>
#        <a href="http://krestyane34.ru/" rel="nofollow" target="_blank">
#         Крестьянская жизнь
#        </a>
#       </li>
#       <li>
#        <a href="http://rodgor-vlg.ru/" rel="nofollow" target="_blank">
#         Родной город
#        </a>
#       </li>
#       <li>
#        <a href="http://vlg-media.ru/" rel="nofollow" target="_blank">
#         Волга-Медиа.ру
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div id="body_wrap">
#    <div id="page">
#     <header class="header header_with_newyear" id="header" role="banner">
#      <style type="text/css">
#       .ZzRwXzM1ODk1XzE1MzQ0NDYwMDA-label-35895, .ZzRwXzM1ODk1XzE1MzQ0NDYwMDA_label_35895:visited{padding: 20px!important;} #block-zz-iv-zz-iv-popular-sidebar{display: none!important;}#block-zz-iv-zz-iv-all-categories .latest_categories_item{min-height: 650px!important;}
#      </style>
#      <a class="header__logo" href="/" rel="home" title="Главная">
#       <span id="logo">
#        <img alt="Волгоградская Правда" class="header__logo-image" src="/sites/all/themes/vpravda/images/header_logo_st_battle_75.png" title="Волгоградская Правда"/>
#       </span>
#      </a>
#      <div id="header_contact">
#       <a href="/contact">
#        Связаться с нами
#       </a>
#      </div>
#      <div id="header_18plus">
#       18+
#      </div>
#      <div class="header__region region region-header">
#       <div class="block block-zz-iv first odd" id="block-zz-iv-zz-iv-search-yandex">
#        <div class="ya-site-form ya-site-form_inited_no" onclick="return {'action':'/rezultaty-poiska','arrow':false,'bg':'transparent','fontsize':12,'fg':'#000000','language':'ru','logo':'rb','publicname':'Поиск по vpravda.ru','suggest':true,'target':'_self','tld':'ru','type':2,'usebigdictionary':true,'searchid':2300525,'input_fg':'#000000','input_bg':'#ffffff','input_fontStyle':'normal','input_fontWeight':'normal','input_placeholder':'Поиск по сайту','input_placeholderColor':'#000000','input_borderColor':'#c0c0c0'}">
#         <form accept-charset="utf-8" action="https://yandex.ru/search/site/" method="get" target="_self">
#          <input name="searchid" type="hidden" value="2300525"/>
#          <input name="l10n" type="hidden" value="ru"/>
#          <input name="reqenc" type="hidden" value=""/>
#          <input name="text" type="search" value=""/>
#          <input type="submit" value="Найти"/>
#         </form>
#        </div>
#        <style type="text/css">
#         .ya-page_js_yes .ya-site-form_inited_no { display: none; }
#        </style>
#        <script type="text/javascript">
#         (function(w,d,c){var s=d.createElement('script'),h=d.getElementsByTagName('script')[0],e=d.documentElement;if((' '+e.className+' ').indexOf(' ya-page_js_yes ')===-1){e.className+=' ya-page_js_yes';}s.type='text/javascript';s.async=true;s.charset='utf-8';s.src=(d.location.protocol==='https:'?'https:':'http:')+'//site.yandex.net/v2.0/js/all.js';h.parentNode.insertBefore(s,h);(w[c]||(w[c]=[])).push(function(){Ya.Site.Form.init()})})(window,document,'yandex_site_callbacks');
#        </script>
#       </div>
#       <div class="block block-menu-block last even" id="block-menu-block-1" role="navigation">
#        <div class="menu-block-wrapper menu-block-1 menu-name-main-menu parent-mlid-0 menu-level-1">
#         <ul class="menu">
#          <li class="menu__item is-leaf first leaf menu-mlid-585">
#           <a class="menu__link" href="/proisshestviya" title="">
#            Происшествия
#           </a>
#          </li>
#          <li class="menu__item is-leaf leaf menu-mlid-586">
#           <a class="menu__link" href="/politika" title="">
#            Политика
#           </a>
#          </li>
#          <li class="menu__item is-leaf leaf menu-mlid-587">
#           <a class="menu__link" href="/obshchestvo" title="">
#            Общество
#           </a>
#          </li>
#          <li class="menu__item is-leaf leaf menu-mlid-588">
#           <a class="menu__link" href="/ekonomika" title="">
#            Экономика
#           </a>
#          </li>
#          <li class="menu__item is-leaf leaf menu-mlid-589">
#           <a class="menu__link" href="/sport" title="">
#            Спорт
#           </a>
#          </li>
#          <li class="menu__item is-leaf leaf menu-mlid-689">
#           <a class="menu__link" href="/chempionat-mira-2018" title="">
#            ЧМ2018
#           </a>
#          </li>
#          <li class="menu__item is-leaf last leaf menu-mlid-590">
#           <a class="menu__link" href="/kultura" title="">
#            Культура
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div id="main">
#      <div class="column" id="content" role="main">
#       <nav class="breadcrumb" role="navigation">
#        <h2 class="element-invisible">
#         Вы здесь
#        </h2>
#        <ol>
#         <li>
#          <a href="/">
#           Главная
#          </a>
#          ›
#         </li>
#         <li>
#          <a href="/politika">
#           Политика
#          </a>
#         </li>
#        </ol>
#       </nav>
#       <a id="main-content">
#       </a>
#       <h1 class="page__title title" id="page-title">
#        Делегация из Германии побывала у волгоградского Вечного огня
#       </h1>
#       <article about="/politika/delegaciya-iz-germanii-pobyvala-u-volgogradskogo-vechnogo-ognya-60334" class="node-60334 node node-article node-promoted view-mode-full clearfix" typeof="sioc:Item foaf:Document">
#        <header>
#         <span class="rdf-meta element-hidden" content="Делегация из Германии побывала у волгоградского Вечного огня" property="dc:title">
#         </span>
#         <span class="rdf-meta element-hidden" content="0" datatype="xsd:integer" property="sioc:num_replies">
#         </span>
#        </header>
#        <div class="field field-name-field-article-date field-type-date field-label-hidden">
#         <div class="field-items">
#          <div class="field-item even">
#           <span class="date-display-single">
#            02.10.2018 в 16:14
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="field field-name-field-article-image field-type-image field-label-hidden">
#         <div class="field-items">
#          <div class="field-item even">
#           <img alt="Делегация из Германии побывала у волгоградского Вечного огня" height="413" src="http://www.vpravda.ru/sites/default/files/styles/photo_620_413/public/article/2018-10-02/59661-1538486573.jpg?itok=pk3605CN" title="Делегация из Германии побывала у волгоградского Вечного огня" typeof="foaf:Image" width="620"/>
#          </div>
#         </div>
#        </div>
#        <div class="field field-name-field-article-lead field-type-text-long field-label-hidden">
#         <div class="field-items">
#          <div class="field-item even">
#           Парламентарии приехали в город-герой с трехдневным визитом. Первым пунктом программы их пребывания стало торжественное возложение цветов на площади Павших Борцов.
#          </div>
#         </div>
#        </div>
#        <div class="field field-name-body field-type-text-with-summary field-label-hidden">
#         <div class="field-items">
#          <div class="field-item even" property="content:encoded">
#           <p>
#            Как сообщает пресс-служба Волгоградской городской думы, в немецкую делегацию вошли парламентарии из партии «Левые».
#           </p>
#           <p>
#            – Гости пробудут в Волгограде три дня в рамках продвижения сотрудничества между Россией и Германией, – отметили в думе.
#           </p>
#           <p>
#            Сегодня, 2 октября, депутаты Европейского парламента, бундестага и региональных парламентов ФРГ в сопровождении волгоградских политиков приняли участие в церемонии возложения венков и живых цветов к Вечному огню. Память сталинградских воинов собравшиеся почтили минутой молчания.
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="field field-name-field-article-author field-type-text field-label-hidden">
#         <div class="field-items">
#          <div class="field-item even">
#           Дарья Сердюкова. Фото предоставлено Волгоградской городской Думой
#          </div>
#         </div>
#        </div>
#        <div class="zz_iv_voting">
#         <div class="zz_iv_voting_inner">
#          <p class="zz_iv_voting_inner_vote">
#           <a class="zz_iv_voting_vote" data-nid="60334" href="#">
#            Нравится [
#            <span class="zz_iv_voting_score">
#             0
#            </span>
#            ]
#           </a>
#          </p>
#          <p class="zz_iv_voting_inner_message">
#          </p>
#         </div>
#         <!-- /.zz_iv_voting_inner -->
#        </div>
#        <!-- /.zz_iv_voting -->
#        <section class="comments comment-wrapper" id="comments">
#         <h2 class="comments__form-title title comment-form">
#          Добавить комментарий
#         </h2>
#         <form accept-charset="UTF-8" action="/comment/reply/60334" class="comment-form" id="comment-form" method="post">
#          <div>
#           <div class="form-item form-type-textfield form-item-name">
#            <label for="edit-name">
#             Ваше имя
#            </label>
#            <input class="form-text" id="edit-name" maxlength="60" name="name" size="30" type="text" value=""/>
#           </div>
#           <div class="field-type-text-long field-name-comment-body field-widget-text-textarea form-wrapper" id="edit-comment-body">
#            <div id="comment-body-add-more-wrapper">
#             <div class="form-item form-type-textarea form-item-comment-body-und-0-value">
#              <label for="edit-comment-body-und-0-value">
#               Ваш комментарий
#               <span class="form-required" title="Это поле обязательно для заполнения.">
#                *
#               </span>
#              </label>
#              <div class="form-textarea-wrapper resizable">
#               <textarea class="text-full form-textarea required" cols="60" id="edit-comment-body-und-0-value" name="comment_body[und][0][value]" rows="5"></textarea>
#              </div>
#             </div>
#            </div>
#           </div>
#           <input name="form_build_id" type="hidden" value="form-GeILUerPqgTm1sFcULqU3HTkSrjCw4qhfYCBKKeBDnE"/>
#           <input name="form_id" type="hidden" value="comment_node_article_form"/>
#           <div class="captcha">
#            <input name="captcha_sid" type="hidden" value="422165"/>
#            <input name="captcha_token" type="hidden" value="45aa63cd557562d60868af51633b07be"/>
#            <input name="captcha_response" type="hidden" value="Google no captcha"/>
#            <div class="g-recaptcha" data-sitekey="6Lew-1wUAAAAAC8-T17gJ9kDs78hH1eq627K-_RY" data-theme="light" data-type="image">
#            </div>
#           </div>
#           <div class="form-actions form-wrapper" id="edit-actions">
#            <input class="form-submit" id="edit-submit" name="op" type="submit" value="Сохранить"/>
#           </div>
#          </div>
#         </form>
#        </section>
#       </article>
#       <div class="block block-zz-iv last even" id="block-zz-iv-zz-iv-addthis-share">
#        <p class="block__title block-title">
#         Поделиться в соцсетях
#        </p>
#        <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5a4216d5a86d9b16" type="text/javascript">
#        </script>
#        <div class="addthis_inline_share_toolbox">
#        </div>
#       </div>
#      </div>
#      <aside class="sidebars">
#       <section class="region region-sidebar-second column sidebar">
#        <div class="block block-views first odd" id="block-views-articles-block-5">
#         <p class="block__title block-title">
#          Последние новости
#         </p>
#         <div class="view view-articles view-id-articles view-display-id-block_5 view-dom-id-a77e3eed37bd83dc3a92ca3fe7ea456c">
#          <div class="view-content">
#           <div class="views-row views-row-1 views-row-odd views-row-first">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 09:20
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/vrach-otorinolaringolog-posovetovala-volgogradcam-nadet-shapki-61110">
#               Врач-оториноларинголог посоветовала волгоградцам надеть шапки
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-2 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 08:43
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/volgogradcam-predlagayut-vybrat-imya-novomu-parku-v-sovetskom-rayone-61109">
#               Волгоградцам предлагают выбрать имя новому парку в Советском районе
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-3 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 08:03
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/usadba/biolog-rasskazal-volgogradcam-kogda-luchshe-obrezat-vinograd-61108">
#               Биолог рассказал волгоградцам, когда лучше обрезать виноград
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-4 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 07:23
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/33-letnyaya-volgogradka-s-redkim-zabolevaniem-vyshla-zamuzh-i-rodila-doch-61107">
#               33-летняя волгоградка с редким генетическим заболеванием родила дочь
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-5 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 06:52
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/samolet-iz-moskvy-ne-mog-priletet-iz-za-tumana-v-aeroportu-volgograda-61106">
#               В аэропорту Волгограда рейс из Москвы задерживался ночью из-за тумана
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-6 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 06:32
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/v-skvere-u-gasitelya-v-volgograde-otkroyut-muzey-pod-otkrytym-nebom-61105">
#               В сквере у «Гасителя» в Волгограде появится музей под открытым небом
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-7 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 23:21
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/proisshestviya/volgogradka-otpravila-moshenniku-165-tysyach-rubley-nadeyas-na-legkuyu-pribyl-61104">
#               Волгоградка отправила мошеннику 165 тысяч рублей, надеясь на легкую прибыль
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-8 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 22:41
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/proisshestviya/pyanogo-muzhchinu-s-nozhom-zaderzhali-v-volgograde-61103">
#               Пьяного мужчину с ножом задержали в Волгограде
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-9 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 22:29
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/sport/v-volzhskom-provedut-sorevnovaniya-po-vsestilevomu-karate-61102">
#               В Волжском проведут соревнования по всестилевому карате
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-10 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 21:54
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/bolee-300-semey-volgogradskoy-oblasti-v-etom-godu-poluchili-pomoshch-na-pokupku-zhilya-61101">
#               Более 300 семей Волгоградской области в этом году получили помощь на покупку жилья
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-11 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 21:46
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/sport/spartak-volgograd-oderzhal-volevuyu-pobedu-nad-dinamo-uralochkoy-61100">
#               «Спартак-Волгоград» одержал волевую победу над «Динамо-Уралочкой»
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-12 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 21:35
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/proisshestviya/lichnyy-dokument-sbezhavshego-ugolovnika-nashli-deti-na-severe-volgograda-61099">
#               Личный документ сбежавшего уголовника нашли дети на севере Волгограда
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-13 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 21:06
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/kultura/v-kamyshine-sostoitsya-festival-teatrov-malyh-gorodov-rossii-61098">
#               В Камышине состоится фестиваль театров малых городов России
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-14 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 20:46
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/v-kamyshine-predpriyatie-bankrot-vyplatilo-byvshim-sotrudnikam-16-mln-rubley-61097">
#               Предприятие-банкрот выплатило бывшим сотрудникам 16 млн рублей под Волгоградом
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-15 views-row-odd views-row-last">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 20:34
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/na-yuge-volgograda-ogromnye-svalki-uberut-po-resheniyu-suda-61096">
#               На юге Волгограда огромные свалки уберут по решению суда
#              </a>
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="block block-block even" id="block-block-5">
#         <p>
#          <a href="http://vpravda.ru/kultura/volgogradskiy-muzykalnyy-teatr-59499">
#           <img alt="Волгоградский музыкальный театр" height="177" src="/sites/default/files/content/images/Photo/2018-09-10-12-33-55-0_61671700.gif" width="300"/>
#          </a>
#         </p>
#        </div>
#        <div class="block block-block odd" id="block-block-7">
#         <p>
#          <a href="http://vpravda.ru/kultura/teatr-kukol-59617">
#           <img alt="" height="150" src="/sites/default/files/content/images/Photo/2018-09-13-12-48-27-0_36775000.gif" width="300"/>
#          </a>
#         </p>
#        </div>
#        <div class="block block-block even" id="block-block-6">
#         <p>
#          <a href="https://basis.myseldon.com/ru?promoCode=VPRAVDA09&amp;PartnerId=15392">
#           <img alt="" height="170" src="/sites/default/files/content/images/Photo/2018-09-12-14-28-46-0_90650200.jpg" width="300"/>
#          </a>
#         </p>
#        </div>
#        <div class="block block-block odd" id="block-block-8">
#         <p>
#          <a href="http://vpravda.ru/kultura/kazachiy-teatr-59628">
#           <img alt="" height="190" src="/sites/default/files/content/images/Photo/2018-09-13-17-29-38-0_66708100.gif" width="300"/>
#          </a>
#         </p>
#        </div>
#        <div class="block block-block even" id="block-block-9">
#         <p>
#          <a href="http://vpravda.ru/kultura/tyuz-2018-59771">
#           <img alt="" height="150" src="/sites/default/files/content/images/Photo/2018-09-17-15-12-09-0_40519200.gif" width="300"/>
#          </a>
#         </p>
#        </div>
#        <div class="block block-block odd" id="block-block-10">
#         <p>
#          <a href="http://vpravda.ru/bez-kategorii/izdatelskiy-dom-volgogradskaya-pravda-primet-na-postoyannuyu-rabotu-menedzhera-po-reklame-60659">
#           <img alt="" height="150" src="/sites/default/files/content/images/Photo/2018-10-09-18-52-38-0_15689200.gif" width="300"/>
#          </a>
#         </p>
#        </div>
#        <div class="block block-block even" id="block-block-1">
#         <div class="banner" style="max-width: 300px;">
#          <script id="r35895" type="text/javascript">
#           (function() {
#         var worker35895,
#             tickerID = 35895,
#             tag = document.getElementById('r'+ tickerID),
#             id = (function(tickerID) {
#                 var now = Math.floor((new Date()).getTime() / 1000 / 3600) * 3600;
#                 if ('btoa' in window)
#                     return btoa('g4p_'+ tickerID +'_'+ now).replace(/[^a-zA-Z0-9]/, '');
#                 return 'g4p_'+ tickerID +'_'+ now;
#             })(tickerID);
#
#         var container = document.createElement('div');
#             container.id = id;
#             container.innerHTML = 'загрузка...';
#         tag.parentNode.insertBefore(container, tag);
#
#         var script = document.createElement('script');
#             script.src = '//js-ru.redtram.com/n4p/0/35/ticker_35895.js';
#             script.type = 'text/javascript';
#             script.charset = 'utf-8';
#             script.onerror = function() {
#                 if (!('atob' in window && 'Worker' in window))
#                     return;
#                 window.rtIsWebSocket = true;
#
#                 var code = '...';
#
#                 function runExternalMessage(data) {
#                     worker35895.postMessage(data);
#                 }
#
#                 worker35895 = new Worker(URL.createObjectURL(
#                     new Blob(["eval(atob('"+code+"'))"], {type: 'text/javascript'})
#                 ));
#
#                 worker35895.onmessage = function(m) {
#                     var json = JSON.parse(m.data),
#                         content = JSON.parse(json)['content'];
#                     eval(content);
#                 };
#
#                 worker35895.postMessage(JSON.stringify({
#                     command: 'init',
#                     informer_id: tickerID,
#                     url: script.src
#                 }));
#             };
#         tag.parentNode.insertBefore(script, tag);
#     })();
#          </script>
#         </div>
#        </div>
#        <div class="block block-block odd" id="block-block-2">
#         <div class="banner_wrapper">
#          <!-- Yandex.RTB R-A-211939-3 -->
#          <div id="yandex_rtb_R-A-211939-3">
#          </div>
#          <script type="text/javascript">
#           (function(w, d, n, s, t) {
#       w[n] = w[n] || [];
#       w[n].push(function() {
#         Ya.Context.AdvManager.render({
#           blockId: "R-A-211939-3",
#           renderTo: "yandex_rtb_R-A-211939-3",
#           async: true
#         });
#       });
#       t = d.getElementsByTagName("script")[0];
#       s = d.createElement("script");
#       s.type = "text/javascript";
#       s.src = "//an.yandex.ru/system/context.js";
#       s.async = true;
#       t.parentNode.insertBefore(s, t);
#     })(this, this.document, "yandexContextAsyncCallbacks");
#          </script>
#         </div>
#         <!-- /.banner_wrapper -->
#        </div>
#        <div class="block block-views even" id="block-views-articles-block-3">
#         <p class="block__title block-title">
#          Выбор редакции
#         </p>
#         <div class="view view-articles view-id-articles view-display-id-block_3 view-dom-id-ab67aaa95ee9c648a974ae2c83ff1406">
#          <div class="view-content">
#           <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#            <div class="views-field views-field-field-article-image">
#             <div class="field-content">
#              <a href="/obshchestvo/postradavshaya-vo-vremya-terakta-22-letnyaya-volgogradka-rodila-doch-60800">
#               <img alt="Пострадавшая во время теракта 22-летняя волгоградка родила дочь" height="200" src="http://www.vpravda.ru/sites/default/files/styles/photo_300_200/public/article/2018-10-12/60255-1539355176.jpg?itok=rl4RVlf6" title="Пострадавшая во время теракта 22-летняя волгоградка родила дочь" typeof="foaf:Image" width="300"/>
#              </a>
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/postradavshaya-vo-vremya-terakta-22-letnyaya-volgogradka-rodila-doch-60800">
#               Пострадавшая во время теракта 22-летняя волгоградка родила дочь
#              </a>
#             </span>
#            </div>
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              12.10 в 17:39
#             </div>
#            </div>
#            <div class="views-field views-field-field-article-lead">
#             <div class="field-content">
#              Ольга Микерина из Волгограда выжила после теракта на железнодорожном вокзале 29 декабря 2013 года. На днях девушка стала счастливой мамой.
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="block block-zz-iv odd" id="block-zz-iv-zz-iv-social-links">
#         <p class="block__title block-title">
#          ВП в соцсетях
#         </p>
#         <div class="social_wrapper clearfix">
#          <a class="social_icon_vk" href="https://vk.com/v_pravda" target="_blank">
#           ВКонтакте
#          </a>
#          <a class="social_icon_ok" href="https://ok.ru/profile/564079075757" target="_blank">
#           Одноклассники
#          </a>
#          <a class="social_icon_in" href="https://www.instagram.com/volgo_pravda/" target="_blank">
#           Instagram
#          </a>
#          <a class="social_icon_fb" href="https://www.facebook.com/vpravda/" target="_blank">
#           Facebook
#          </a>
#         </div>
#        </div>
#        <div class="block block-zz-iv last even" id="block-zz-iv-zz-iv-banners-sidebar">
#         <div class="banner_wrapper">
#          <a href="http://vlg-media.ru/media/pdf/price2015-2016_%2001.09.15.pdf" rel="nofollow" target="_blank">
#           <img alt="" src="/sites/all/themes/vpravda/images/banners/2017-05-31-subscribe.jpg"/>
#          </a>
#         </div>
#         <!-- /.banner_wrapper -->
#        </div>
#       </section>
#      </aside>
#     </div>
#     <footer class="region region-footer" id="footer">
#      <div class="block block-zz-iv first last odd" id="block-zz-iv-zz-iv-all-categories">
#       <div class="latest_categories_wrapper">
#        <div class="latest_categories_item odd col_1">
#         <h2 class="block__title">
#          Происшествия
#         </h2>
#         <div class="view view-articles view-id-articles view-display-id-block_1 view-dom-id-5eb1b26b0c5a2e549de0f65992fdb1f2">
#          <div class="view-content">
#           <div class="views-row views-row-1 views-row-odd views-row-first">
#            <div class="views-field views-field-field-article-image">
#             <div class="field-content">
#              <a href="/proisshestviya/volgogradka-otpravila-moshenniku-165-tysyach-rubley-nadeyas-na-legkuyu-pribyl-61104">
#               <img alt="Волгоградка отправила мошеннику 165 тысяч рублей, надеясь на легкую прибыль" height="67" src="http://vpravda.ru/sites/default/files/styles/photo_100_67/public/article/2018-10-19/60621-1539980510.jpg?itok=sA8XQjq2" title="Волгоградка отправила мошеннику 165 тысяч рублей, надеясь на легкую прибыль" typeof="foaf:Image" width="100"/>
#              </a>
#             </div>
#            </div>
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 23:21
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/proisshestviya/volgogradka-otpravila-moshenniku-165-tysyach-rubley-nadeyas-na-legkuyu-pribyl-61104">
#               Волгоградка отправила мошеннику 165 тысяч рублей, надеясь на легкую прибыль
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-2 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 22:41
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/proisshestviya/pyanogo-muzhchinu-s-nozhom-zaderzhali-v-volgograde-61103">
#               Пьяного мужчину с ножом задержали в Волгограде
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-3 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 21:35
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/proisshestviya/lichnyy-dokument-sbezhavshego-ugolovnika-nashli-deti-na-severe-volgograda-61099">
#               Личный документ сбежавшего уголовника нашли дети на севере Волгограда
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-4 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 18:44
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/proisshestviya/volgogradec-popalsya-na-vzyatke-policeyskomu-61091">
#               Волгоградец попался на взятке полицейскому
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-5 views-row-odd views-row-last">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 17:42
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/proisshestviya/direktor-firmy-osuzhden-na-8-let-za-podkup-v-volgograde-61088">
#               Директор фирмы осужден на 8 лет за подкуп в Волгограде
#              </a>
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="view-footer">
#           <a href="/proisshestviya">
#            Архив рубрики
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- /.latest_categories_item odd col_1 -->
#        <div class="latest_categories_item even col_2">
#         <h2 class="block__title">
#          Политика
#         </h2>
#         <div class="view view-articles view-id-articles view-display-id-block_1 view-dom-id-4fa9e3d2fa295b7925fa04acbc2c05f6">
#          <div class="view-content">
#           <div class="views-row views-row-1 views-row-odd views-row-first">
#            <div class="views-field views-field-field-article-image">
#             <div class="field-content">
#              <a href="/politika/v-volgograde-ushla-v-otstavku-predsedatel-komiteta-po-fizicheskoy-kulture-i-sportu-60826">
#               <img alt="В Волгограде ушла в отставку председатель комитета по физической культуре и спорту " height="67" src="http://vpravda.ru/sites/default/files/styles/photo_100_67/public/article/2018-10-13/60285-1539429088.jpg?itok=-vBdioGx" title="В Волгограде ушла в отставку председатель комитета по физической культуре и спорту " typeof="foaf:Image" width="100"/>
#              </a>
#             </div>
#            </div>
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              13.10 в 14:09
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/politika/v-volgograde-ushla-v-otstavku-predsedatel-komiteta-po-fizicheskoy-kulture-i-sportu-60826">
#               В Волгограде ушла в отставку председатель комитета по физической культуре и спорту
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-2 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              09.10 в 14:36
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/politika/volgogradskaya-oblast-razvivaet-delovye-otnosheniya-s-regionami-uzbekistana-60647">
#               Волгоградская область развивает деловые отношения с регионами Узбекистана
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-3 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              05.10 в 15:32
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/politika/novyy-glava-voroshilovskogo-rayona-naznachen-v-volgograde-60480">
#               Новый глава Ворошиловского района назначен в Волгограде
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-4 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              02.10 в 16:14
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/politika/delegaciya-iz-germanii-pobyvala-u-volgogradskogo-vechnogo-ognya-60334">
#               Делегация из Германии побывала у волгоградского Вечного огня
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-5 views-row-odd views-row-last">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              24.09 в 11:22
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/politika/igor-voronin-prines-prisyagu-i-snova-stal-glavoy-goroda-volzhskogo-60007">
#               Игорь Воронин принес присягу и снова стал главой города Волжского
#              </a>
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="view-footer">
#           <a href="/politika">
#            Архив рубрики
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- /.latest_categories_item odd col_1 -->
#        <div class="latest_categories_item odd col_3">
#         <h2 class="block__title">
#          Общество
#         </h2>
#         <div class="view view-articles view-id-articles view-display-id-block_1 view-dom-id-7ca8d01c29d4116bf677fbd5b403e40e">
#          <div class="view-content">
#           <div class="views-row views-row-1 views-row-odd views-row-first">
#            <div class="views-field views-field-field-article-image">
#             <div class="field-content">
#              <a href="/obshchestvo/vrach-otorinolaringolog-posovetovala-volgogradcam-nadet-shapki-61110">
#               <img alt="Врач-оториноларинголог посоветовала волгоградцам надеть шапки" height="67" src="http://vpravda.ru/sites/default/files/styles/photo_100_67/public/article/2018-10-20/60628-1540017225.jpg?itok=n8xKZl_3" title="Врач-оториноларинголог посоветовала волгоградцам надеть шапки" typeof="foaf:Image" width="100"/>
#              </a>
#             </div>
#            </div>
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 09:20
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/vrach-otorinolaringolog-posovetovala-volgogradcam-nadet-shapki-61110">
#               Врач-оториноларинголог посоветовала волгоградцам надеть шапки
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-2 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 08:43
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/obshchestvo/volgogradcam-predlagayut-vybrat-imya-novomu-parku-v-sovetskom-rayone-61109">
#               Волгоградцам предлагают выбрать имя новому парку в Советском районе
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-3 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              20.10 в 07:23
#             </div>
#            </div>
# ...
#              </a>
#             </div>
#            </div>
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 17:01
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/ekonomika/finansovaya-sistema-volgogradskoy-oblasti-priznana-stabilnoy-i-bezopasnoy-61087">
#               Финансовая система Волгоградской области признана стабильной и безопасной
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-2 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 13:34
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/ekonomika/andrey-bocharov-v-regione-sformirovany-resursy-dlya-realizacii-proryvnyh-proektov-61073">
#               Андрей Бочаров: «В регионе сформированы ресурсы для реализации прорывных проектов»
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-3 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              18.10 в 19:45
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/ekonomika/volgogradskih-predprinimateley-nauchili-privlekat-investicii-v-biznes-61049">
#               Волгоградских предпринимателей научили привлекать инвестиции в бизнес
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-4 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              18.10 в 16:11
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/ekonomika/rostelekom-predstavil-mobilnoe-prilozhenie-dlya-udalennoy-identifikacii-v-edinoy-biometricheskoy-sisteme-61038">
#               «Ростелеком» представил мобильное приложение для удаленной идентификации в Единой биометрической системе
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-5 views-row-odd views-row-last">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              18.10 в 15:38
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/ekonomika/bank-vozrozhdenie-uluchshil-usloviya-potrebitelskogo-kredita-dlya-polnogo-schastya-61036">
#               Банк «Возрождение» улучшил условия потребительского кредита «Для полного счастья»
#              </a>
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="view-footer">
#           <a href="/ekonomika">
#            Архив рубрики
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- /.latest_categories_item odd col_1 -->
#        <div class="latest_categories_item odd col_2">
#         <h2 class="block__title">
#          Спорт
#         </h2>
#         <div class="view view-articles view-id-articles view-display-id-block_1 view-dom-id-bb416fd7ed15c0551e70793c0e33a4cc">
#          <div class="view-content">
#           <div class="views-row views-row-1 views-row-odd views-row-first">
#            <div class="views-field views-field-field-article-image">
#             <div class="field-content">
#              <a href="/sport/v-volzhskom-provedut-sorevnovaniya-po-vsestilevomu-karate-61102">
#               <img alt="В Волжском проведут соревнования по всестилевому каратэ" height="67" src="http://vpravda.ru/sites/default/files/styles/photo_100_67/public/article/2018-10-19/60619-1539977381.jpg?itok=os47lToR" title="В Волжском проведут соревнования по всестилевому каратэ" typeof="foaf:Image" width="100"/>
#              </a>
#             </div>
#            </div>
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 22:29
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/sport/v-volzhskom-provedut-sorevnovaniya-po-vsestilevomu-karate-61102">
#               В Волжском проведут соревнования по всестилевому карате
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-2 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 21:46
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/sport/spartak-volgograd-oderzhal-volevuyu-pobedu-nad-dinamo-uralochkoy-61100">
#               «Спартак-Волгоград» одержал волевую победу над «Динамо-Уралочкой»
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-3 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 19:41
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/sport/volgogradskiy-bokser-supertyazh-stal-bronzovym-prizerom-chempionata-rossii-61094">
#               Волгоградский боксер-супертяж стал бронзовым призером чемпионата России
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-4 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 19:30
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/sport/v-volgograde-proshel-detskiy-turnir-po-mini-futbolu-61093">
#               В Волгограде прошел детский турнир по мини-футболу
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-5 views-row-odd views-row-last">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              18.10 в 22:29
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/sport/kapitan-volgogradskogo-spartaka-gorbunova-sygrala-na-pyaterku-61053">
#               Капитан волгоградского «Спартака» Горбунова сыграла на «пятерку»
#              </a>
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="view-footer">
#           <a href="/sport">
#            Архив рубрики
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- /.latest_categories_item odd col_1 -->
#        <div class="latest_categories_item even col_3">
#         <h2 class="block__title">
#          Культура
#         </h2>
#         <div class="view view-articles view-id-articles view-display-id-block_1 view-dom-id-0d9a5148e3adc0758a65b39314bb7040">
#          <div class="view-content">
#           <div class="views-row views-row-1 views-row-odd views-row-first">
#            <div class="views-field views-field-field-article-image">
#             <div class="field-content">
#              <a href="/kultura/v-kamyshine-sostoitsya-festival-teatrov-malyh-gorodov-rossii-61098">
#               <img alt="В Камышине состоится фестиваль театров малых городов России" height="67" src="http://vpravda.ru/sites/default/files/styles/photo_100_67/public/article/2018-10-19/60615-1539972413.jpg?itok=lC18keQY" title="В Камышине состоится фестиваль театров малых городов России" typeof="foaf:Image" width="100"/>
#              </a>
#             </div>
#            </div>
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 21:06
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/kultura/v-kamyshine-sostoitsya-festival-teatrov-malyh-gorodov-rossii-61098">
#               В Камышине состоится фестиваль театров малых городов России
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-2 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              19.10 в 13:57
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/kultura/v-volgograde-pokazhut-pechatnuyu-grafiku-s-kartin-van-goga-i-gogena-61075">
#               В Волгограде покажут печатную графику с картин Ван Гога и Гогена
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-3 views-row-odd">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              18.10 в 22:49
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/kultura/vpervye-v-volgograde-otkryty-dni-neigrovogo-kino-61055">
#               Впервые в Волгограде открыты Дни неигрового кино
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-4 views-row-even">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              17.10 в 21:28
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/kultura/boevye-podrugi-spoyut-na-centralnom-rynke-v-volgograde-61010">
#               «Боевые подруги» споют на Центральном рынке в Волгограде
#              </a>
#             </span>
#            </div>
#           </div>
#           <div class="views-row views-row-5 views-row-odd views-row-last">
#            <div class="views-field views-field-field-article-date">
#             <div class="field-content">
#              16.10 в 18:34
#             </div>
#            </div>
#            <div class="views-field views-field-title">
#             <span class="field-content">
#              <a href="/kultura/maksim-dunaevskiy-reshil-postavit-nad-volgogradcami-eksperiment-60960">
#               Максим Дунаевский решил поставить над волгоградцами эксперимент
#              </a>
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="view-footer">
#           <a href="/kultura">
#            Архив рубрики
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- /.latest_categories_item odd col_1 -->
#       </div>
#       <!-- /.latest_categories_wrapper -->
#      </div>
#     </footer>
#    </div>
#   </div>
#   <div id="page_bottom">
#    <div class="region region-bottom">
#     <div class="block block-zz-iv first last odd" id="block-zz-iv-zz-iv-footer">
#      ﻿
#      <div class="footer_wrapper clearfix">
#       <div class="col">
#        <a href="/">
#         <img alt="" src="/sites/all/themes/vpravda/images/footer_logo.png"/>
#        </a>
#       </div>
#       <!-- /.col -->
#       <div class="col">
#        <p>
#         © 2017 ООО "ИД "Волгоградская правда"
#         <br/>
#         г. Волгоград.
#        </p>
#       </div>
#       <!-- /.col -->
#       <div class="col">
#        <div class="clearfix">
#         <div class="col_links">
#          <p>
#           <a href="/archive">
#            Архив материалов
#           </a>
#           <br/>
#           <a href="/sitemap">
#            Карта сайта
#           </a>
#           <br/>
#           <a href="/reklama">
#            Реклама
#           </a>
#          </p>
#         </div>
#         <div class="col_counter">
#          <!--LiveInternet counter-->
#          <script type="text/javascript">
#           document.write("<a href='//www.liveinternet.ru/click' "+
# "target=_blank><img src='//counter.yadro.ru/hit?t45.4;r"+
# escape(document.referrer)+((typeof(screen)=="undefined")?"":
# ";s"+screen.width+"*"+screen.height+"*"+(screen.colorDepth?
# screen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+
# ";h"+escape(document.title.substring(0,80))+";"+Math.random()+
# "' alt='' title='LiveInternet' "+
# "border='0' width='31' height='31'><\/a>")
#          </script>
#          <!--/LiveInternet-->
#         </div>
#        </div>
#       </div>
#       <!-- /.col -->
#      </div>
#      <!-- /.footer_wrapper clearfix -->
#      <div class="info">
#       <p>
#        Сетевое издание "Волгоградская правда.ру" зарегистрировано Федеральной службой по надзору в сфере связи, информационных технологий и массовых коммуникаций, свидетельство: ЭЛ № ФС77-72702 от 23 апреля 2018 года.
#       </p>
#       <p>
#        Учредители: администрация Волгоградской области, комитет по делам территориальных образований, внутренней и информационной политики Волгоградской области, общество с ограниченной ответственностью "Издательский дом "Волгоградская правда".
#       </p>
#       <p>
#        И.о. главного редактора: Екатерина Валентиновна Голод.
#       </p>
#       <p>
#        Контакты: (8442) 43-60-49, id-vpravda@ya.ru; рекламная служба: (8442) 43-61-24, 8-927-067-76-15
#       </p>
#       <p>
#        Адрес редакции и издателя: 400131, Волгоград, ул. Краснознаменская, 7, (8442)43-60-49.
#       </p>
#       <p>
#        Все права защищены ©ООО "ИД "Волгоградская правда". Условия использования информации: для текстов – с обязательным указанием источника («Волгоградская правда» или vpravda.ru) и гиперссылкой, для фото, видео – только с письменного разрешения редакции.
#       </p>
#       <p>
#        Письма читателей не рецензируются и не возвращаются. Публикуемые материалы не всегда отражают точку зрения редакции. Редакция не несет ответственности за достоверность рекламной информации. Все рекламируемые товары и услуги имеют необходимые лицензии и сертификаты.
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="http://www.vpravda.ru/modules/statistics/statistics.js?p9wo8n">
#   </script>
#   <!-- Yandex.Metrika counter -->
#   <script type="text/javascript">
#    (function (d, w, c) {
#       (w[c] = w[c] || []).push(function() {
#         try {
#           w.yaCounter7968763 = new Ya.Metrika({
#             id:7968763,
#             clickmap:true,
#             trackLinks:true,
#             accurateTrackBounce:true
#           });
#         } catch(e) { }
#       });
#
#       var n = d.getElementsByTagName("script")[0],
#         s = d.createElement("script"),
#         f = function () { n.parentNode.insertBefore(s, n); };
#       s.type = "text/javascript";
#       s.async = true;
#       s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#       if (w.opera == "[object Opera]") {
#         d.addEventListener("DOMContentLoaded", f, false);
#       } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/7968763" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Yandex.Metrika counter -->
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-111535465-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-111535465-1');
#   </script>
#  </body>
# </html>

# %%
   # titleTag['id'] = 'page-title'
import re
title = soup.findAll(id='page-title')
title_clean = title[0].get_text()


important = soup.findAll(attrs={"class" : "field-item even"})
time = important[0].get_text()
preview = important[2].get_text()
text = important[3].get_text()
author = important[4].get_text()
author_clean = autho

print('title',title_clean)
print('preview',preview)
print('time',time)
print('text',text)
print('author',author)
# Out:
# title Делегация из Германии побывала у волгоградского Вечного огня
# preview Парламентарии приехали в город-герой с трехдневным визитом. Первым пунктом программы их пребывания стало торжественное возложение цветов на площади Павших Борцов.
# time 02.10.2018 в 16:14
# text Как сообщает пресс-служба Волгоградской городской думы, в немецкую делегацию вошли парламентарии из партии «Левые».
# – Гости пробудут в Волгограде три дня в рамках продвижения сотрудничества между Россией и Германией, – отметили в думе.
# Сегодня, 2 октября, депутаты Европейского парламента, бундестага и региональных парламентов ФРГ в сопровождении волгоградских политиков приняли участие в церемонии возложения венков и живых цветов к Вечному огню. Память сталинградских воинов собравшиеся почтили минутой молчания.
# author Дарья Сердюкова. Фото предоставлено Волгоградской городской Думой
