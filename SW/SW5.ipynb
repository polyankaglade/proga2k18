# %%
import urllib.request
from bs4 import BeautifulSoup

link = "http://n-i-p.ru/articles/media/2018/6/15/grantopoluchateli-rajona-budut-razvivat-zhivotnovodstvo/"
f = urllib.request.urlopen(link)
myfile = f.read()
soup = BeautifulSoup(myfile,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- SERVER_NAME: server1.inovaco.ru -->
#   <!-- SITE_ID:     project_smi3_802 -->
#   <!-- IP:          92.242.59.6 -->
#   <title>
#    Грантополучатели района  будут развивать животноводство - Поиск - Статьи - «Наша иртышская правда». Массовая газета Большереченского района Омской области
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="http://n-i-p.ru/articles/media/2018/6/15/grantopoluchateli-rajona-budut-razvivat-zhivotnovodstvo/" rel="canonical">
# ...

# %%
print(soup.get_text())
# Out:
# Грантополучатели района  будут развивать животноводство - Поиск - Статьи - «Наша иртышская правда». Массовая газета Большереченского района Омской области
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     $(window).on('load', function () {
#         if (window['grecaptcha'])
#             $(document).ajaxComplete(function (event, xhr) {
#                 if (xhr.responseText.indexOf('g-recaptcha') > -1)
#                     $(document.body).find('.g-recaptcha').each(function () {
#                         if (!this.hasChildNodes())
#                             grecaptcha.render(this, {'sitekey': this.getAttribute('data-sitekey')});
#                     });
#
#             });
#     });
#
#
#
#
#
#
#
#
#
# Меню
#
#
# 16+
#
# «Наша иртышская правда». Массовая газета Большереченского района Омской области
# Версия для слабовидящих
#
#
#
# Вверх/вниз
#
#     body {
#         background: #404040;
#     }
#
#
# ...

# %%
soup.findAll('img')
# Out:
# [<img src="//storage.inovaco.ru/media/cache/65/3c/a8/7c/a5/6b/653ca87ca56bbd2c13e7c4cdd330d1f8.jpg"/>,
#  <img alt="Яндекс.Метрика" onclick="try{Ya.Metrika.informer({i:this,id:21819016,lang:'ru'});return false}catch(e){}" src="//bs.yandex.ru/informer/21819016/3_1_FFFFFFFF_EFEFEFFF_0_pageviews" style="width:88px; height:31px; border:0;" title="Яндекс.Метрика: данные за сегодня (просмотры, визиты и уникальные посетители)"/>,
#  <img alt="" src="//mc.yandex.ru/watch/21819016" style="position:absolute; left:-9999px;"/>,
#  <img src="/htest.gif" style="display: block; width: 1px; height: 1px"/>]

# %%
x = soup.find('div',{'class':'uil-mo-image-annotation__image'})
x.find('img').get('src')
# Out:
# '//storage.inovaco.ru/media/cache/65/3c/a8/7c/a5/6b/653ca87ca56bbd2c13e7c4cdd330d1f8.jpg'
